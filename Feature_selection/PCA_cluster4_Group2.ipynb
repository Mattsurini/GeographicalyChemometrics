# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data = pd.read_csv('/content/drive/MyDrive/Working Space/Data_coffee/Data_coffee_complete_correlationWithGroup.csv')
Data
# Out:
#     field1 Name     NewCode code  Groupping  Sweetness      L     A      B  \
# 0        0  DC1    DC8001-1   F1          1       17.5  44.83  0.45  11.11
# 1        1  DC1    DC8001-2   F1          1       17.5  44.83  0.45  11.11
# 2        2  DC1    DC8001-3   F1          1       17.5  44.83  0.45  11.11
# 3        3  DC1    DC8001-4   F1          1       17.5  44.83  0.45  11.11
# 4        4  DC1    DC8001-5   F1          1       17.5  44.83  0.45  11.11
# ..     ...  ...         ...  ...        ...        ...    ...   ...    ...
# 64     221  BK1  BK-10001-2  F48          6       15.0  49.48  1.25  11.67
# 65     222  BK1  BK-10001-3  F48          6       15.0  49.48  1.25  11.67
# 66     225  BK3  BK-10003-1  F50          6       17.0  52.42  0.81  12.40
# 67     226  BK3  BK-10003-2  F50          6       17.0  52.42  0.81  12.40
# 68     227  BK3  BK-10003-3  F50          6       17.0  52.42  0.81  12.40
#
#     Total_phenol  ...  Serine  alanine  glycine  threonine  glutamic_acid  \
# 0           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 1           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 2           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 3           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 4           2.56  ...  104.17   203.30    13.49      26.27         410.72
# ..           ...  ...     ...      ...      ...        ...            ...
# 64          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 65          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 66          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 67          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 68          1.99  ...  187.75   396.23    36.27      45.11         317.60
#
#     proline  histidine  arginine  leucine  phynylalanine
# 0     48.40      26.76    136.15    52.01          61.76
# 1     48.40      26.76    136.15    52.01          61.76
# 2     48.40      26.76    136.15    52.01          61.76
# 3     48.40      26.76    136.15    52.01          61.76
# 4     48.40      26.76    136.15    52.01          61.76
# ..      ...        ...       ...      ...            ...
# 64    63.88      37.02    381.68    74.05         152.09
# 65    63.88      37.02    381.68    74.05         152.09
# 66    67.28      52.47    295.35    68.86         139.61
# 67    67.28      52.47    295.35    68.86         139.61
# 68    67.28      52.47    295.35    68.86         139.61
#
# [69 rows x 35 columns]

# %%
feature = ['Serine',
 'phynylalanine',
 'Apartic_acid',
 'leucine',
 'alanine',
 'arginine',
 'proline',
 'histidine',
 'K',
 'threonine']
feature
# Out:
# ['Serine',
#  'phynylalanine',
#  'Apartic_acid',
#  'leucine',
#  'alanine',
#  'arginine',
#  'proline',
#  'histidine',
#  'K',
#  'threonine']

# %%
feature_corr = Data[feature].corr()
feature_uncorr = feature_corr.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) <= 0.05 else 'background-color: white')
feature_uncorr
# Out:
# <style type="text/css">
# #T_64a99_row0_col0, #T_64a99_row0_col1, #T_64a99_row0_col2, #T_64a99_row0_col3, #T_64a99_row0_col4, #T_64a99_row0_col5, #T_64a99_row0_col6, #T_64a99_row0_col7, #T_64a99_row0_col8, #T_64a99_row0_col9, #T_64a99_row1_col0, #T_64a99_row1_col1, #T_64a99_row1_col2, #T_64a99_row1_col3, #T_64a99_row1_col4, #T_64a99_row1_col5, #T_64a99_row1_col6, #T_64a99_row1_col7, #T_64a99_row1_col8, #T_64a99_row1_col9, #T_64a99_row2_col0, #T_64a99_row2_col1, #T_64a99_row2_col2, #T_64a99_row2_col3, #T_64a99_row2_col4, #T_64a99_row2_col5, #T_64a99_row2_col6, #T_64a99_row2_col7, #T_64a99_row2_col8, #T_64a99_row2_col9, #T_64a99_row3_col0, #T_64a99_row3_col1, #T_64a99_row3_col2, #T_64a99_row3_col3, #T_64a99_row3_col4, #T_64a99_row3_col5, #T_64a99_row3_col6, #T_64a99_row3_col7, #T_64a99_row3_col8, #T_64a99_row3_col9, #T_64a99_row4_col0, #T_64a99_row4_col1, #T_64a99_row4_col2, #T_64a99_row4_col3, #T_64a99_row4_col4, #T_64a99_row4_col5, #T_64a99_row4_col6, #T_64a99_row4_col7, #T_64a99_row4_col8, #T_64a99_row4_col9, #T_64a99_row5_col0, #T_64a99_row5_col1, #T_64a99_row5_col2, #T_64a99_row5_col3, #T_64a99_row5_col4, #T_64a99_row5_col5, #T_64a99_row5_col6, #T_64a99_row5_col7, #T_64a99_row5_col8, #T_64a99_row5_col9, #T_64a99_row6_col0, #T_64a99_row6_col1, #T_64a99_row6_col2, #T_64a99_row6_col3, #T_64a99_row6_col4, #T_64a99_row6_col5, #T_64a99_row6_col6, #T_64a99_row6_col7, #T_64a99_row6_col8, #T_64a99_row6_col9, #T_64a99_row7_col0, #T_64a99_row7_col1, #T_64a99_row7_col2, #T_64a99_row7_col3, #T_64a99_row7_col4, #T_64a99_row7_col5, #T_64a99_row7_col6, #T_64a99_row7_col7, #T_64a99_row7_col8, #T_64a99_row7_col9, #T_64a99_row8_col0, #T_64a99_row8_col1, #T_64a99_row8_col2, #T_64a99_row8_col3, #T_64a99_row8_col4, #T_64a99_row8_col5, #T_64a99_row8_col6, #T_64a99_row8_col7, #T_64a99_row8_col8, #T_64a99_row8_col9, #T_64a99_row9_col0, #T_64a99_row9_col1, #T_64a99_row9_col2, #T_64a99_row9_col3, #T_64a99_row9_col4, #T_64a99_row9_col5, #T_64a99_row9_col6, #T_64a99_row9_col7, #T_64a99_row9_col8, #T_64a99_row9_col9 {
#   background-color: white;
# }
# </style>
# <table id="T_64a99_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Serine</th>
#       <th class="col_heading level0 col1" >phynylalanine</th>
#       <th class="col_heading level0 col2" >Apartic_acid</th>
#       <th class="col_heading level0 col3" >leucine</th>
#       <th class="col_heading level0 col4" >alanine</th>
#       <th class="col_heading level0 col5" >arginine</th>
#       <th class="col_heading level0 col6" >proline</th>
#       <th class="col_heading level0 col7" >histidine</th>
#       <th class="col_heading level0 col8" >K</th>
#       <th class="col_heading level0 col9" >threonine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64a99_level0_row0" class="row_heading level0 row0" >Serine</th>
#       <td id="T_64a99_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_64a99_row0_col1" class="data row0 col1" >0.924850</td>
#       <td id="T_64a99_row0_col2" class="data row0 col2" >0.792443</td>
#       <td id="T_64a99_row0_col3" class="data row0 col3" >0.738585</td>
#       <td id="T_64a99_row0_col4" class="data row0 col4" >0.870840</td>
#       <td id="T_64a99_row0_col5" class="data row0 col5" >0.875872</td>
#       <td id="T_64a99_row0_col6" class="data row0 col6" >0.806679</td>
#       <td id="T_64a99_row0_col7" class="data row0 col7" >0.752647</td>
#       <td id="T_64a99_row0_col8" class="data row0 col8" >0.370950</td>
#       <td id="T_64a99_row0_col9" class="data row0 col9" >0.882385</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row1" class="row_heading level0 row1" >phynylalanine</th>
#       <td id="T_64a99_row1_col0" class="data row1 col0" >0.924850</td>
#       <td id="T_64a99_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_64a99_row1_col2" class="data row1 col2" >0.773710</td>
#       <td id="T_64a99_row1_col3" class="data row1 col3" >0.762542</td>
#       <td id="T_64a99_row1_col4" class="data row1 col4" >0.962616</td>
#       <td id="T_64a99_row1_col5" class="data row1 col5" >0.953879</td>
#       <td id="T_64a99_row1_col6" class="data row1 col6" >0.856724</td>
#       <td id="T_64a99_row1_col7" class="data row1 col7" >0.816402</td>
#       <td id="T_64a99_row1_col8" class="data row1 col8" >0.525078</td>
#       <td id="T_64a99_row1_col9" class="data row1 col9" >0.953396</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row2" class="row_heading level0 row2" >Apartic_acid</th>
#       <td id="T_64a99_row2_col0" class="data row2 col0" >0.792443</td>
#       <td id="T_64a99_row2_col1" class="data row2 col1" >0.773710</td>
#       <td id="T_64a99_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_64a99_row2_col3" class="data row2 col3" >0.507453</td>
#       <td id="T_64a99_row2_col4" class="data row2 col4" >0.725109</td>
#       <td id="T_64a99_row2_col5" class="data row2 col5" >0.763245</td>
#       <td id="T_64a99_row2_col6" class="data row2 col6" >0.630672</td>
#       <td id="T_64a99_row2_col7" class="data row2 col7" >0.817996</td>
#       <td id="T_64a99_row2_col8" class="data row2 col8" >0.591268</td>
#       <td id="T_64a99_row2_col9" class="data row2 col9" >0.698058</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row3" class="row_heading level0 row3" >leucine</th>
#       <td id="T_64a99_row3_col0" class="data row3 col0" >0.738585</td>
#       <td id="T_64a99_row3_col1" class="data row3 col1" >0.762542</td>
#       <td id="T_64a99_row3_col2" class="data row3 col2" >0.507453</td>
#       <td id="T_64a99_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_64a99_row3_col4" class="data row3 col4" >0.852823</td>
#       <td id="T_64a99_row3_col5" class="data row3 col5" >0.716884</td>
#       <td id="T_64a99_row3_col6" class="data row3 col6" >0.966035</td>
#       <td id="T_64a99_row3_col7" class="data row3 col7" >0.723482</td>
#       <td id="T_64a99_row3_col8" class="data row3 col8" >0.531622</td>
#       <td id="T_64a99_row3_col9" class="data row3 col9" >0.900534</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row4" class="row_heading level0 row4" >alanine</th>
#       <td id="T_64a99_row4_col0" class="data row4 col0" >0.870840</td>
#       <td id="T_64a99_row4_col1" class="data row4 col1" >0.962616</td>
#       <td id="T_64a99_row4_col2" class="data row4 col2" >0.725109</td>
#       <td id="T_64a99_row4_col3" class="data row4 col3" >0.852823</td>
#       <td id="T_64a99_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_64a99_row4_col5" class="data row4 col5" >0.937464</td>
#       <td id="T_64a99_row4_col6" class="data row4 col6" >0.931651</td>
#       <td id="T_64a99_row4_col7" class="data row4 col7" >0.835933</td>
#       <td id="T_64a99_row4_col8" class="data row4 col8" >0.610539</td>
#       <td id="T_64a99_row4_col9" class="data row4 col9" >0.986963</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row5" class="row_heading level0 row5" >arginine</th>
#       <td id="T_64a99_row5_col0" class="data row5 col0" >0.875872</td>
#       <td id="T_64a99_row5_col1" class="data row5 col1" >0.953879</td>
#       <td id="T_64a99_row5_col2" class="data row5 col2" >0.763245</td>
#       <td id="T_64a99_row5_col3" class="data row5 col3" >0.716884</td>
#       <td id="T_64a99_row5_col4" class="data row5 col4" >0.937464</td>
#       <td id="T_64a99_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_64a99_row5_col6" class="data row5 col6" >0.793447</td>
#       <td id="T_64a99_row5_col7" class="data row5 col7" >0.738760</td>
#       <td id="T_64a99_row5_col8" class="data row5 col8" >0.429482</td>
#       <td id="T_64a99_row5_col9" class="data row5 col9" >0.899621</td>
#     </tr>
#     <tr>
#       <th id="T_64a99_level0_row6" class="row_heading level0 row6" >proline</th>
#       <td id="T_64a99_row6_col0" class="data row6 col0" >0.806679</td>
#       <td id="T_64a99_row6_col1" class="data row6 col1" >0.856724</td>
#       <td id="T_64a99_row6_col2" class="data row6 col2" >0.630672</td>
#       <td id="T_64a99_row6_col3" class="data row6 col3" >0.9

# %%
X = Data[feature]
scaler = StandardScaler()
X_t = scaler.fit_transform(X)

# %%
pca = PCA(n_components=X_t.shape[1])

pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}') # Eigenvalues
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=10) = [8.19096853e+00 9.00220498e-01 6.74031898e-01 2.09461057e-01
#  9.92890218e-02 4.64890916e-02 1.68794395e-02 9.71928564e-03
#  1.29576442e-32 8.66005720e-34]
# explained_variance_ratio (n_components=10) = [8.07225884e-01 8.87173824e-02 6.64263320e-02 2.06425390e-02
#  9.78500504e-03 4.58153366e-03 1.66348100e-03 9.57842643e-04
#  1.27698523e-33 8.53454913e-35]
# sum explained_variance_ratio = 1.0000000000000002

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
scree_plot(X, 5, True, True)

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=Data[feature].columns,
                  columns=[f'PC{n+1}' for n in range(pca.components_.shape[0])]).round(4) #Eigenvectors
# dpc
dpc.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) > .5 else 'background-color: white')
# Out:
# <style type="text/css">
# #T_f60f0_row0_col0, #T_f60f0_row0_col1, #T_f60f0_row0_col2, #T_f60f0_row0_col3, #T_f60f0_row0_col5, #T_f60f0_row0_col6, #T_f60f0_row0_col7, #T_f60f0_row0_col8, #T_f60f0_row0_col9, #T_f60f0_row1_col0, #T_f60f0_row1_col1, #T_f60f0_row1_col2, #T_f60f0_row1_col3, #T_f60f0_row1_col4, #T_f60f0_row1_col5, #T_f60f0_row1_col7, #T_f60f0_row1_col8, #T_f60f0_row1_col9, #T_f60f0_row2_col0, #T_f60f0_row2_col1, #T_f60f0_row2_col3, #T_f60f0_row2_col4, #T_f60f0_row2_col5, #T_f60f0_row2_col6, #T_f60f0_row2_col7, #T_f60f0_row2_col8, #T_f60f0_row2_col9, #T_f60f0_row3_col0, #T_f60f0_row3_col1, #T_f60f0_row3_col3, #T_f60f0_row3_col4, #T_f60f0_row3_col5, #T_f60f0_row3_col6, #T_f60f0_row3_col7, #T_f60f0_row3_col8, #T_f60f0_row3_col9, #T_f60f0_row4_col0, #T_f60f0_row4_col1, #T_f60f0_row4_col2, #T_f60f0_row4_col3, #T_f60f0_row4_col4, #T_f60f0_row4_col5, #T_f60f0_row4_col6, #T_f60f0_row4_col8, #T_f60f0_row4_col9, #T_f60f0_row5_col0, #T_f60f0_row5_col1, #T_f60f0_row5_col2, #T_f60f0_row5_col3, #T_f60f0_row5_col4, #T_f60f0_row5_col5, #T_f60f0_row5_col6, #T_f60f0_row5_col7, #T_f60f0_row5_col8, #T_f60f0_row5_col9, #T_f60f0_row6_col0, #T_f60f0_row6_col1, #T_f60f0_row6_col2, #T_f60f0_row6_col3, #T_f60f0_row6_col4, #T_f60f0_row6_col5, #T_f60f0_row6_col6, #T_f60f0_row6_col7, #T_f60f0_row6_col9, #T_f60f0_row7_col0, #T_f60f0_row7_col1, #T_f60f0_row7_col2, #T_f60f0_row7_col3, #T_f60f0_row7_col4, #T_f60f0_row7_col6, #T_f60f0_row7_col7, #T_f60f0_row7_col8, #T_f60f0_row7_col9, #T_f60f0_row8_col0, #T_f60f0_row8_col2, #T_f60f0_row8_col3, #T_f60f0_row8_col4, #T_f60f0_row8_col5, #T_f60f0_row8_col6, #T_f60f0_row8_col7, #T_f60f0_row8_col8, #T_f60f0_row8_col9, #T_f60f0_row9_col0, #T_f60f0_row9_col1, #T_f60f0_row9_col2, #T_f60f0_row9_col3, #T_f60f0_row9_col4, #T_f60f0_row9_col5, #T_f60f0_row9_col6, #T_f60f0_row9_col7, #T_f60f0_row9_col8 {
#   background-color: white;
# }
# #T_f60f0_row0_col4, #T_f60f0_row1_col6, #T_f60f0_row2_col2, #T_f60f0_row3_col2, #T_f60f0_row4_col7, #T_f60f0_row6_col8, #T_f60f0_row7_col5, #T_f60f0_row8_col1, #T_f60f0_row9_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f60f0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PC1</th>
#       <th class="col_heading level0 col1" >PC2</th>
#       <th class="col_heading level0 col2" >PC3</th>
#       <th class="col_heading level0 col3" >PC4</th>
#       <th class="col_heading level0 col4" >PC5</th>
#       <th class="col_heading level0 col5" >PC6</th>
#       <th class="col_heading level0 col6" >PC7</th>
#       <th class="col_heading level0 col7" >PC8</th>
#       <th class="col_heading level0 col8" >PC9</th>
#       <th class="col_heading level0 col9" >PC10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f60f0_level0_row0" class="row_heading level0 row0" >Serine</th>
#       <td id="T_f60f0_row0_col0" class="data row0 col0" >0.317700</td>
#       <td id="T_f60f0_row0_col1" class="data row0 col1" >0.326600</td>
#       <td id="T_f60f0_row0_col2" class="data row0 col2" >0.199000</td>
#       <td id="T_f60f0_row0_col3" class="data row0 col3" >-0.394300</td>
#       <td id="T_f60f0_row0_col4" class="data row0 col4" >0.544100</td>
#       <td id="T_f60f0_row0_col5" class="data row0 col5" >0.107500</td>
#       <td id="T_f60f0_row0_col6" class="data row0 col6" >-0.384500</td>
#       <td id="T_f60f0_row0_col7" class="data row0 col7" >-0.160700</td>
#       <td id="T_f60f0_row0_col8" class="data row0 col8" >0.327900</td>
#       <td id="T_f60f0_row0_col9" class="data row0 col9" >-0.092300</td>
#     </tr>
#     <tr>
#       <th id="T_f60f0_level0_row1" class="row_heading level0 row1" >phynylalanine</th>
#       <td id="T_f60f0_row1_col0" class="data row1 col0" >0.337300</td>
#       <td id="T_f60f0_row1_col1" class="data row1 col1" >0.199500</td>
#       <td id="T_f60f0_row1_col2" class="data row1 col2" >0.121100</td>
#       <td id="T_f60f0_row1_col3" class="data row1 col3" >0.299500</td>
#       <td id="T_f60f0_row1_col4" class="data row1 col4" >0.273900</td>
#       <td id="T_f60f0_row1_col5" class="data row1 col5" >0.114700</td>
#       <td id="T_f60f0_row1_col6" class="data row1 col6" >0.771800</td>
#       <td id="T_f60f0_row1_col7" class="data row1 col7" >-0.076900</td>
#       <td id="T_f60f0_row1_col8" class="data row1 col8" >0.075500</td>
#       <td id="T_f60f0_row1_col9" class="data row1 col9" >-0.215800</td>
#     </tr>
#     <tr>
#       <th id="T_f60f0_level0_row2" class="row_heading level0 row2" >Apartic_acid</th>
#       <td id="T_f60f0_row2_col0" class="data row2 col0" >0.285100</td>
#       <td id="T_f60f0_row2_col1" class="data row2 col1" >-0.106900</td>
#       <td id="T_f60f0_row2_col2" class="data row2 col2" >0.642000</td>
#       <td id="T_f60f0_row2_col3" class="data row2 col3" >-0.408400</td>
#       <td id="T_f60f0_row2_col4" class="data row2 col4" >-0.483900</td>
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"ba ...

# %%
pca = PCA(n_components=2)

X_pca=pca.fit_transform(X_t)

X_pca
# Out:
# array([[-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-2.28084856,  0.66274632],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.9815044 , -0.99345195],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-0.73432207, -0.06797893],
#        [-3.50008055, -0.92849226],
#        [-3.50008055, -0.92849226],
#        [-3.50008055, -0.92849226],
#        [-3.50008055, -0.92849226],
#        [-3.50008055, -0.92849226],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 0.72718601,  0.76057084],
#        [ 4.18932176, -0.78906271],
#        [ 4.18932176, -0.78906271],
#        [ 4.18932176, -0.78906271],
#        [ 4.18932176, -0.78906271],
#        [ 4.18932176, -0.78906271],
#        [ 4.96556098, -0.53127764],
#        [ 4.96556098, -0.53127764],
#        [ 4.96556098, -0.53127764],
#        [ 4.96556098, -0.53127764],
#        [ 4.96556098, -0.53127764],
#        [ 4.71698589,  2.86585268],
#        [ 4.71698589,  2.86585268],
#        [ 4.71698589,  2.86585268],
#        [ 5.57861145, -0.82453688],
#        [ 5.57861145, -0.82453688],
#        [ 5.57861145, -0.82453688]])

# %%
dd=pd.concat([pd.DataFrame(pca.transform(X_t), 
                           columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]), 
              Data[['Groupping']]], axis = 'columns')

dd
# Out:
#          PC1       PC2  Groupping
# 0  -2.280849  0.662746          1
# 1  -2.280849  0.662746          1
# 2  -2.280849  0.662746          1
# 3  -2.280849  0.662746          1
# 4  -2.280849  0.662746          1
# ..       ...       ...        ...
# 64  4.716986  2.865853          6
# 65  4.716986  2.865853          6
# 66  5.578611 -0.824537          6
# 67  5.578611 -0.824537          6
# 68  5.578611 -0.824537          6
#
# [69 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
scatter = plt.scatter(dd['PC1'],dd['PC2'],cmap='Set1', c=Data.Groupping.astype('category').cat.codes)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(b=None)
plt.legend(handles=scatter.legend_elements()[0], 
           labels = ['1','2','3','4','5','6'],
           title = "Groupping")
plt.show()
