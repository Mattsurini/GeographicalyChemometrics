# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data = pd.read_csv('/content/drive/MyDrive/Working Space/Data_coffee/Data_coffee_complete_correlationWithGroup.csv')
Data
# Out:
#     field1 Name     NewCode code  Groupping  Sweetness      L     A      B  \
# 0        0  DC1    DC8001-1   F1          1       17.5  44.83  0.45  11.11
# 1        1  DC1    DC8001-2   F1          1       17.5  44.83  0.45  11.11
# 2        2  DC1    DC8001-3   F1          1       17.5  44.83  0.45  11.11
# 3        3  DC1    DC8001-4   F1          1       17.5  44.83  0.45  11.11
# 4        4  DC1    DC8001-5   F1          1       17.5  44.83  0.45  11.11
# ..     ...  ...         ...  ...        ...        ...    ...   ...    ...
# 64     221  BK1  BK-10001-2  F48          6       15.0  49.48  1.25  11.67
# 65     222  BK1  BK-10001-3  F48          6       15.0  49.48  1.25  11.67
# 66     225  BK3  BK-10003-1  F50          6       17.0  52.42  0.81  12.40
# 67     226  BK3  BK-10003-2  F50          6       17.0  52.42  0.81  12.40
# 68     227  BK3  BK-10003-3  F50          6       17.0  52.42  0.81  12.40
#
#     Total_phenol  ...  Serine  alanine  glycine  threonine  glutamic_acid  \
# 0           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 1           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 2           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 3           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 4           2.56  ...  104.17   203.30    13.49      26.27         410.72
# ..           ...  ...     ...      ...      ...        ...            ...
# 64          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 65          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 66          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 67          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 68          1.99  ...  187.75   396.23    36.27      45.11         317.60
#
#     proline  histidine  arginine  leucine  phynylalanine
# 0     48.40      26.76    136.15    52.01          61.76
# 1     48.40      26.76    136.15    52.01          61.76
# 2     48.40      26.76    136.15    52.01          61.76
# 3     48.40      26.76    136.15    52.01          61.76
# 4     48.40      26.76    136.15    52.01          61.76
# ..      ...        ...       ...      ...            ...
# 64    63.88      37.02    381.68    74.05         152.09
# 65    63.88      37.02    381.68    74.05         152.09
# 66    67.28      52.47    295.35    68.86         139.61
# 67    67.28      52.47    295.35    68.86         139.61
# 68    67.28      52.47    295.35    68.86         139.61
#
# [69 rows x 35 columns]

# %%
feature = ['arginine',
 'L',
 'Antioxidant',
 'glycine',
 'B',
 'A',
 'phynylalanine',
 'Apartic_acid',
 'leucine',
 'Serine',
 'alanine',
 'threonine',
 'proline',
 'histidine',
 'caffeic_acid',
 'K',
 'Lactic_acid']
feature
# Out:
# ['arginine',
#  'L',
#  'Antioxidant',
#  'glycine',
#  'B',
#  'A',
#  'phynylalanine',
#  'Apartic_acid',
#  'leucine',
#  'Serine',
#  'alanine',
#  'threonine',
#  'proline',
#  'histidine',
#  'caffeic_acid',
#  'K',
#  'Lactic_acid']

# %%
feature_corr = Data[feature].corr()
feature_uncorr = feature_corr.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) <= 0.05 else 'background-color: white')
feature_uncorr
# Out:
# <style type="text/css">
# #T_f063e_row0_col0, #T_f063e_row0_col1, #T_f063e_row0_col2, #T_f063e_row0_col3, #T_f063e_row0_col5, #T_f063e_row0_col6, #T_f063e_row0_col7, #T_f063e_row0_col8, #T_f063e_row0_col9, #T_f063e_row0_col10, #T_f063e_row0_col11, #T_f063e_row0_col12, #T_f063e_row0_col13, #T_f063e_row0_col14, #T_f063e_row0_col15, #T_f063e_row0_col16, #T_f063e_row1_col0, #T_f063e_row1_col1, #T_f063e_row1_col2, #T_f063e_row1_col3, #T_f063e_row1_col4, #T_f063e_row1_col5, #T_f063e_row1_col6, #T_f063e_row1_col7, #T_f063e_row1_col8, #T_f063e_row1_col10, #T_f063e_row1_col11, #T_f063e_row1_col12, #T_f063e_row1_col13, #T_f063e_row1_col14, #T_f063e_row1_col15, #T_f063e_row1_col16, #T_f063e_row2_col0, #T_f063e_row2_col1, #T_f063e_row2_col2, #T_f063e_row2_col3, #T_f063e_row2_col4, #T_f063e_row2_col5, #T_f063e_row2_col6, #T_f063e_row2_col7, #T_f063e_row2_col8, #T_f063e_row2_col9, #T_f063e_row2_col10, #T_f063e_row2_col11, #T_f063e_row2_col12, #T_f063e_row2_col13, #T_f063e_row2_col14, #T_f063e_row2_col15, #T_f063e_row2_col16, #T_f063e_row3_col0, #T_f063e_row3_col1, #T_f063e_row3_col2, #T_f063e_row3_col3, #T_f063e_row3_col4, #T_f063e_row3_col5, #T_f063e_row3_col6, #T_f063e_row3_col7, #T_f063e_row3_col8, #T_f063e_row3_col9, #T_f063e_row3_col10, #T_f063e_row3_col11, #T_f063e_row3_col12, #T_f063e_row3_col13, #T_f063e_row3_col14, #T_f063e_row3_col15, #T_f063e_row3_col16, #T_f063e_row4_col1, #T_f063e_row4_col2, #T_f063e_row4_col3, #T_f063e_row4_col4, #T_f063e_row4_col5, #T_f063e_row4_col8, #T_f063e_row4_col9, #T_f063e_row4_col12, #T_f063e_row4_col13, #T_f063e_row4_col14, #T_f063e_row4_col15, #T_f063e_row4_col16, #T_f063e_row5_col0, #T_f063e_row5_col1, #T_f063e_row5_col2, #T_f063e_row5_col3, #T_f063e_row5_col4, #T_f063e_row5_col5, #T_f063e_row5_col6, #T_f063e_row5_col7, #T_f063e_row5_col8, #T_f063e_row5_col9, #T_f063e_row5_col10, #T_f063e_row5_col11, #T_f063e_row5_col12, #T_f063e_row5_col13, #T_f063e_row5_col14, #T_f063e_row5_col15, #T_f063e_row5_col16, #T_f063e_row6_col0, #T_f063e_row6_col1, #T_f063e_row6_col2, #T_f063e_row6_col3, #T_f063e_row6_col5, #T_f063e_row6_col6, #T_f063e_row6_col7, #T_f063e_row6_col8, #T_f063e_row6_col9, #T_f063e_row6_col10, #T_f063e_row6_col11, #T_f063e_row6_col12, #T_f063e_row6_col13, #T_f063e_row6_col14, #T_f063e_row6_col15, #T_f063e_row6_col16, #T_f063e_row7_col0, #T_f063e_row7_col1, #T_f063e_row7_col2, #T_f063e_row7_col3, #T_f063e_row7_col5, #T_f063e_row7_col6, #T_f063e_row7_col7, #T_f063e_row7_col8, #T_f063e_row7_col9, #T_f063e_row7_col10, #T_f063e_row7_col11, #T_f063e_row7_col12, #T_f063e_row7_col13, #T_f063e_row7_col14, #T_f063e_row7_col15, #T_f063e_row7_col16, #T_f063e_row8_col0, #T_f063e_row8_col1, #T_f063e_row8_col2, #T_f063e_row8_col3, #T_f063e_row8_col4, #T_f063e_row8_col5, #T_f063e_row8_col6, #T_f063e_row8_col7, #T_f063e_row8_col8, #T_f063e_row8_col9, #T_f063e_row8_col10, #T_f063e_row8_col11, #T_f063e_row8_col12, #T_f063e_row8_col13, #T_f063e_row8_col14, #T_f063e_row8_col15, #T_f063e_row8_col16, #T_f063e_row9_col0, #T_f063e_row9_col2, #T_f063e_row9_col3, #T_f063e_row9_col4, #T_f063e_row9_col5, #T_f063e_row9_col6, #T_f063e_row9_col7, #T_f063e_row9_col8, #T_f063e_row9_col9, #T_f063e_row9_col10, #T_f063e_row9_col11, #T_f063e_row9_col12, #T_f063e_row9_col13, #T_f063e_row9_col14, #T_f063e_row9_col15, #T_f063e_row9_col16, #T_f063e_row10_col0, #T_f063e_row10_col1, #T_f063e_row10_col2, #T_f063e_row10_col3, #T_f063e_row10_col5, #T_f063e_row10_col6, #T_f063e_row10_col7, #T_f063e_row10_col8, #T_f063e_row10_col9, #T_f063e_row10_col10, #T_f063e_row10_col11, #T_f063e_row10_col12, #T_f063e_row10_col13, #T_f063e_row10_col14, #T_f063e_row10_col15, #T_f063e_row10_col16, #T_f063e_row11_col0, #T_f063e_row11_col1, #T_f063e_row11_col2, #T_f063e_row11_col3, #T_f063e_row11_col5, #T_f063e_row11_col6, #T_f063e_row11_col7, #T_f063e_row11_col8, #T_f063e_row11_col9, #T_f063e_row11_col10, #T_f063e_row11_col11, #T_f063e_row11_col12, #T_f063e_row11_col13, #T_f063e_row11_col14, #T_f063e_row11_col15, #T_f063e_row11_col16, #T_f063e_row12_col0, #T_f063e_row12_col1, #T_f ...
#   background-color: white;
# }
# #T_f063e_row0_col4, #T_f063e_row1_col9, #T_f063e_row4_col0, #T_f063e_row4_col6, #T_f063e_row4_col7, #T_f063e_row4_col10, #T_f063e_row4_col11, #T_f063e_row6_col4, #T_f063e_row7_col4, #T_f063e_row9_col1, #T_f063e_row10_col4, #T_f063e_row11_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f063e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >arginine</th>
#       <th class="col_heading level0 col1" >L</th>
#       <th class="col_heading level0 col2" >Antioxidant</th>
#       <th class="col_heading level0 col3" >glycine</th>
#       <th class="col_heading level0 col4" >B</th>
#       <th class="col_heading level0 col5" >A</th>
#       <th class="col_heading level0 col6" >phynylalanine</th>
#       <th class="col_heading level0 col7" >Apartic_acid</th>
#       <th class="col_heading level0 col8" >leucine</th>
#       <th class="col_heading level0 col9" >Serine</th>
#       <th class="col_heading level0 col10" >alanine</th>
#       <th class="col_heading level0 col11" >threonine</th>
#       <th class="col_heading level0 col12" >proline</th>
#       <th class="col_heading level0 col13" >histidine</th>
#       <th class="col_heading level0 col14" >caffeic_acid</th>
#       <th class="col_heading level0 col15" >K</th>
#       <th class="col_heading level0 col16" >Lactic_acid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f063e_level0_row0" class="row_heading level0 row0" >arginine</th>
#       <td id="T_f063e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f063e_row0_col1" class="data row0 col1" >0.144081</td>
#       <td id="T_f063e_row0_col2" class="data row0 col2" >0.276384</td>
#       <td id="T_f063e_row0_col3" class="data row0 col3" >0.583193</td>
#       <td id="T_f063e_row0_col4" class="data row0 col4" >0.048754</td>
#       <td id="T_f063e_row0_col5" class="data row0 col5" >0.396495</td>
#       <td id="T_f063e_row0_col6" class="data row0 col6" >0.953879</td>
#       <td id="T_f063e_row0_col7" class="data row0 col7" >0.763245</td>
#       <td id="T_f063e_row0_col8" class="data row0 col8" >0.716884</td>
#       <td id="T_f063e_row0_col9" class="data row0 col9" >0.87

# %%
X = Data[feature]
scaler = StandardScaler()
X_t = scaler.fit_transform(X)

# %%
pca = PCA(n_components=X_t.shape[1])

pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}') # Eigenvalues
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=17) = [9.98509150e+00 3.47002807e+00 1.55325714e+00 9.72842652e-01
#  4.99468446e-01 4.21141731e-01 2.90098631e-01 5.80718324e-02
#  2.06271289e-31 3.93695438e-32 2.47655694e-32 2.12246699e-32
#  7.60196858e-33 3.32251747e-33 7.06165803e-34 2.85837106e-34
#  2.00144279e-34]
# explained_variance_ratio (n_components=17) = [5.78845884e-01 2.01161048e-01 9.00438919e-02 5.63966755e-02
#  2.89546925e-02 2.44140134e-02 1.68173119e-02 3.36648304e-03
#  1.19577559e-32 2.28229239e-33 1.43568518e-33 1.23041564e-33
#  4.40693831e-34 1.92609708e-34 4.09371480e-35 1.65702670e-35
#  1.16025669e-35]
# sum explained_variance_ratio = 1.0

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
scree_plot(X, 5, True, True)

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=Data[feature].columns,
                  columns=[f'PC{n+1}' for n in range(pca.components_.shape[0])]).round(4) #Eigenvectors
# dpc
dpc.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) > .5 else 'background-color: white')
# Out:
# <style type="text/css">
# #T_0ae46_row0_col0, #T_0ae46_row0_col1, #T_0ae46_row0_col2, #T_0ae46_row0_col3, #T_0ae46_row0_col4, #T_0ae46_row0_col5, #T_0ae46_row0_col6, #T_0ae46_row0_col7, #T_0ae46_row0_col8, #T_0ae46_row0_col9, #T_0ae46_row0_col10, #T_0ae46_row0_col11, #T_0ae46_row0_col12, #T_0ae46_row0_col13, #T_0ae46_row0_col14, #T_0ae46_row0_col15, #T_0ae46_row0_col16, #T_0ae46_row1_col0, #T_0ae46_row1_col1, #T_0ae46_row1_col2, #T_0ae46_row1_col3, #T_0ae46_row1_col4, #T_0ae46_row1_col5, #T_0ae46_row1_col6, #T_0ae46_row1_col8, #T_0ae46_row1_col9, #T_0ae46_row1_col10, #T_0ae46_row1_col11, #T_0ae46_row1_col12, #T_0ae46_row1_col13, #T_0ae46_row1_col14, #T_0ae46_row1_col15, #T_0ae46_row1_col16, #T_0ae46_row2_col0, #T_0ae46_row2_col1, #T_0ae46_row2_col2, #T_0ae46_row2_col3, #T_0ae46_row2_col4, #T_0ae46_row2_col5, #T_0ae46_row2_col6, #T_0ae46_row2_col7, #T_0ae46_row2_col8, #T_0ae46_row2_col9, #T_0ae46_row2_col10, #T_0ae46_row2_col11, #T_0ae46_row2_col12, #T_0ae46_row2_col13, #T_0ae46_row2_col14, #T_0ae46_row2_col15, #T_0ae46_row2_col16, #T_0ae46_row3_col0, #T_0ae46_row3_col1, #T_0ae46_row3_col2, #T_0ae46_row3_col3, #T_0ae46_row3_col4, #T_0ae46_row3_col5, #T_0ae46_row3_col6, #T_0ae46_row3_col7, #T_0ae46_row3_col8, #T_0ae46_row3_col9, #T_0ae46_row3_col10, #T_0ae46_row3_col12, #T_0ae46_row3_col13, #T_0ae46_row3_col14, #T_0ae46_row3_col15, #T_0ae
0ae46_row10_col7, #T_0ae46_row10_col8, #T_0ae46_row10_col9, #T_0ae46_row10_col10, #T_0ae46_row10_col11, #T_0ae46_row10_col12, #T_0ae46_row10_col13, #T_0ae46_row10_col14, #T_0ae46_row10_col15, #T_0ae46_row10_col16, #T_0ae46_row11_col0, #T_0ae46_row11_col1, #T_0ae46_row11_col2, #T_0ae46_row11_col3, #T_0ae46_row11_col4, #T_0ae46_row11_col5, #T_0ae46_row11_col6, #T_0ae46_row11_col7, #T_0ae46_row11_col8, #T_0ae46_row11_col9, #T_0ae46_row11_col10, #T_0ae46_row11_col11, #T_0ae46_row11_col12, #T_0ae46_row ...
#   background-color: white;
# }
# #T_0ae46_row1_col7, #T_0ae46_row3_col11, #T_0ae46_row4_col5, #T_0ae46_row5_col4, #T_0ae46_row6_col7, #T_0ae46_row9_col12, #T_0ae46_row11_col15, #T_0ae46_row13_col16, #T_0ae46_row15_col2, #T_0ae46_row15_col10, #T_0ae46_row16_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0ae46_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PC1</th>
#       <th class="col_heading level0 col1" >PC2</th>
#       <th class="col_heading level0 col2" >PC3</th>
#       <th class="col_heading level0 col3" >PC4</th>
#       <th class="col_heading level0 col4" >PC5</th>
#       <th class="col_heading level0 col5" >PC6</th>
#       <th class="col_heading level0 col6" >PC7</th>
#       <th class="col_heading level0 col7" >PC8</th>
#       <th class="col_heading level0 col8" >PC9</th>
#       <th class="col_heading level0 col9" >PC10</th>
#       <th class="col_heading level0 col10" >PC11</th>
#       <th class="col_heading level0 col11" >PC12</th>
#       <th class="col_heading level0 col12" >PC13</th>
#       <th class="col_heading level0 col13" >PC14</th>
#       <th class="col_heading level0 col14" >PC15</th>
#       <th class="col_heading level0 col15" >PC16</th>
#       <th class="col_heading level0 col16" >PC17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ae46_level0_row0" class="row_heading level0 row0" >arginine</th>
#       <td id="T_0ae46_row0_col0" class="data row0 col0" >0.281200</td>
#       <td id="T_0ae46_row0_col1" class="data row0 col1" >-0.131400</td>
#       <td id="T_0ae46_row0_col2" class="data row0 col2" >0.159900</td>
#       <td id="T_0ae46_row0_col3" class="data row0 col3" >0.154100</td>
#       <td id="T_0ae46_row0_col4" class="data row0 col4" >-0.066600</td>
#       <td id="T_0ae46_row0_col5" class="data row0 col5" >0.417800</td>
#       <td id="T_0ae46_row0_col6" class="data row0 col6" >0.252200</td>
#       <td id="T_0ae46_row0_col7" class="data row0 col7" >-0.380900</td>
#       <td id="T_0ae46_row0_col8" class="data row0 col8" >0.464700</td>
#       <td id="T_0ae46_row0_col9" class="data row0 col9" >-0.104300</td>
#       <td id="T_0ae46_row0_col10" class="data row0

# %%
import yellowbrick.features as yb
visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
visualizer.fit_transform(X)
visualizer.show()

# %%
pca1 = PCA(n_components= 2)
components = pca1.fit_transform(X_t)
fig = px.scatter(components, x = 0, y = 1, color = Data['Groupping'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor ...

# %%
pca = PCA(n_components=2)

X_pca=pca.fit_transform(X_t)

X_pca
# Out:
# array([[-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-3.09201046, -1.09002215],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [-1.67989339, -1.14100914],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [ 1.00299464,  3.50798164],
#        [-2.68993139,  3.55389878],
#        [-2.68993139,  3.55389878],
#        [-2.68993139,  3.55389878],
#        [-2.68993139,  3.55389878],
#        [-2.68993139,  3.55389878],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 1.52271409,  1.16431724],
#        [ 4.1374632 , -0.82542597],
#        [ 4.1374632 , -0.82542597],
#        [ 4.1374632 , -0.82542597],
#        [ 4.1374632 , -0.82542597],
#        [ 4.1374632 , -0.82542597],
#        [ 5.34262215, -0.50345435],
#        [ 5.34262215, -0.50345435],
#        [ 5.34262215, -0.50345435],
#        [ 5.34262215, -0.50345435],
#        [ 5.34262215, -0.50345435],
#        [ 4.64380972, -2.04589067],
#        [ 4.64380972, -2.04589067],
#        [ 4.64380972, -2.04589067],
#        [ 5.70455619, -1.52264409],
#        [ 5.70455619, -1.52264409],
#        [ 5.70455619, -1.52264409]])

# %%
dd=pd.concat([pd.DataFrame(pca.transform(X_t), 
                           columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]), 
              Data[['Groupping']]], axis = 'columns')

dd
# Out:
#          PC1       PC2  Groupping
# 0  -3.092010 -1.090022          1
# 1  -3.092010 -1.090022          1
# 2  -3.092010 -1.090022          1
# 3  -3.092010 -1.090022          1
# 4  -3.092010 -1.090022          1
# ..       ...       ...        ...
# 64  4.643810 -2.045891          6
# 65  4.643810 -2.045891          6
# 66  5.704556 -1.522644          6
# 67  5.704556 -1.522644          6
# 68  5.704556 -1.522644          6
#
# [69 rows x 3 columns]

# %%
dd.to_csv('PCA_Maybast.csv')

# %%
plt.figure(figsize=(10,10))
scatter = plt.scatter(dd['PC1'],dd['PC2'],cmap='Set1', c=Data.Groupping.astype('category').cat.codes)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(b=None)
plt.legend(handles=scatter.legend_elements()[0], 
           labels = ['1','2','3','4','5','6'],
           title = "Groupping")
plt.show()
