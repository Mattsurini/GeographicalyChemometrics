# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data = pd.read_csv('/content/drive/MyDrive/Working Space/Data_coffee/Data_coffee_complete_correlationWithGroup.csv')
Data
# Out:
#     field1 Name     NewCode code  Groupping  Sweetness      L     A      B  \
# 0        0  DC1    DC8001-1   F1          1       17.5  44.83  0.45  11.11
# 1        1  DC1    DC8001-2   F1          1       17.5  44.83  0.45  11.11
# 2        2  DC1    DC8001-3   F1          1       17.5  44.83  0.45  11.11
# 3        3  DC1    DC8001-4   F1          1       17.5  44.83  0.45  11.11
# 4        4  DC1    DC8001-5   F1          1       17.5  44.83  0.45  11.11
# ..     ...  ...         ...  ...        ...        ...    ...   ...    ...
# 64     221  BK1  BK-10001-2  F48          6       15.0  49.48  1.25  11.67
# 65     222  BK1  BK-10001-3  F48          6       15.0  49.48  1.25  11.67
# 66     225  BK3  BK-10003-1  F50          6       17.0  52.42  0.81  12.40
# 67     226  BK3  BK-10003-2  F50          6       17.0  52.42  0.81  12.40
# 68     227  BK3  BK-10003-3  F50          6       17.0  52.42  0.81  12.40
#
#     Total_phenol  ...  Serine  alanine  glycine  threonine  glutamic_acid  \
# 0           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 1           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 2           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 3           2.56  ...  104.17   203.30    13.49      26.27         410.72
# 4           2.56  ...  104.17   203.30    13.49      26.27         410.72
# ..           ...  ...     ...      ...      ...        ...            ...
# 64          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 65          0.94  ...  185.40   417.97    25.97      44.10         457.11
# 66          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 67          1.99  ...  187.75   396.23    36.27      45.11         317.60
# 68          1.99  ...  187.75   396.23    36.27      45.11         317.60
#
#     proline  histidine  arginine  leucine  phynylalanine
# 0     48.40      26.76    136.15    52.01          61.76
# 1     48.40      26.76    136.15    52.01          61.76
# 2     48.40      26.76    136.15    52.01          61.76
# 3     48.40      26.76    136.15    52.01          61.76
# 4     48.40      26.76    136.15    52.01          61.76
# ..      ...        ...       ...      ...            ...
# 64    63.88      37.02    381.68    74.05         152.09
# 65    63.88      37.02    381.68    74.05         152.09
# 66    67.28      52.47    295.35    68.86         139.61
# 67    67.28      52.47    295.35    68.86         139.61
# 68    67.28      52.47    295.35    68.86         139.61
#
# [69 rows x 35 columns]

# %%
feature = ['Fe',
 'Theobromine',
 'fluctose_arabinise',
 'sucrose_maltose',
 'glutamic_acid',
 'Sweetness']
feature
# Out:
# ['Fe',
#  'Theobromine',
#  'fluctose_arabinise',
#  'sucrose_maltose',
#  'glutamic_acid',
#  'Sweetness']

# %%
feature_corr = Data[feature].corr()
feature_uncorr = feature_corr.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) <= 0.05 else 'background-color: white')
feature_uncorr
# Out:
# <style type="text/css">
row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a5f68_row3_col4" class="data row3 col4" >0.530883</td>
#       <td id="T_a5f68_row3_col5" class="data row3 col5" >0.440534</td>
#     </tr>
#     <tr>
#       <th id="T_a5f68_level0_row4" class="row_heading level0 row4" >glutamic_acid</th>
#       <td id="T_a5f68_row4_col0" class="data row4 col0" >0.442571</td>
#       <td id="T_a5f68_row4_col1" class="data row4 col1" >0.325519</td>
#       <td id="T_a5f68_row4_col2" class="data row4 col2" >0.340354</td>
#       <td id="T_a5f68_row4_col3" class="data row4 col3" >0.530883</td>
#       <td id="T_a5f68_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a5f68_row4_col5" class="data row4 col5" >0.796020</td>
#     </tr>
#     <tr>
#       <th id="T_a5f68_level0_row5" class="row_heading level0 row5" >Sweetness</th>
#       <td id="T_a5f68_row5_col0" class="data row5 col0" >0.491743</td>
#       <td id="T_a5f68_row5_col1" class="data row5 col1" >0.132393</td>
#       <td id="T_a5f68_row5_col2" class="data row5 col2" >0.209602</td>
#       <td id="T_a5f68_row5_col3" class="data row5 col3" >0.440534</td>
#       <td id="T_a5f68_row5_col4" class="data row5 col4" >0.796020</td>
#       <td id="T_a5f68_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X = Data[feature]
scaler = StandardScaler()
X_t = scaler.fit_transform(X)

# %%
pca = PCA(n_components=X_t.shape[1])

pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}') # Eigenvalues
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=6) = [3.68015864 1.24528157 0.86335683 0.24527667 0.03969454 0.01446705]
# explained_variance_ratio (n_components=6) = [0.6044705  0.204539   0.1418074  0.04028699 0.00651988 0.00237623]
# sum explained_variance_ratio = 1.0

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
scree_plot(X, 5, True, True)

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=Data[feature].columns,
                  columns=[f'PC{n+1}' for n in range(pca.components_.shape[0])]).round(4) #Eigenvectors
# dpc
dpc.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) > .5 else 'background-color: white')
# Out:
# <style type="text/css">
# #T_ad988_row0_col0, #T_ad988_row0_col1, #T_ad988_row0_col2, #T_ad988_row0_col3, #T_ad988_row0_col5, #T_ad988_row1_col0, #T_ad988_row1_col1, #T_ad988_row1_col3, #T_ad988_row1_col4, #T_ad988_row1_col5, #T_ad988_row2_col0, #T_ad988_row2_col1, #T_ad988_row2_col2, #T_ad988_row2_col3, #T_ad988_row2_col4, #T_ad988_row3_col0, #T_ad988_row3_col1, #T_ad988_row3_col2, #T_ad988_row3_col3, #T_ad988_row3_col5, #T_ad988_row4_col0, #T_ad988_row4_col2, #T_ad988_row4_col4, #T_ad988_row4_col5, #T_ad988_row5_col0, #T_ad988_row5_col2, #T_ad988_row5_col4, #T_ad988_row5_col5 {
#   background-color: white;
# }
# #T_ad988_row0_col4, #T_ad988_row1_col2, #T_ad988_row2_col5, #T_ad988_row3_col4, #T_ad988_row4_col1, #T_ad988_row4_col3, #T_ad988_row5_col1, #T_ad988_row5_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_ad988_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PC1</th>
#       <th class="col_heading level0 col1" >PC2</th>
#       <th class="col_heading level0 col2" >PC3</th>
#       <th class="col_heading level0 col3" >PC4</th>
#       <th class="col_heading level0 col4" >PC5</th>
#       <th class="col_heading level0 col5" >PC6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad988_level0_row0" class="row_heading level0 row0" >Fe</th>
#       <td id="T_ad988_row0_col0" class="data row0 col0" >0.489200</td>
#       <td id="T_ad988_row0_col1" class="data row0 col1" >0.217700</td>
#       <td id="T_ad988_row0_col2" class="data row0 col2" >0.106100</td>
#       <td id="T_ad988_row0_col3" class="data row0 col3" >-0.454600</td>
#       <td id="T_ad988_row0_col4" class="data row0 col4" >-0.547200</td>
#       <td id="T_ad988_row0_col5" class="data row0 col5" >0.442700</td>
#     </tr>
#     <tr>
#       <th id="T_ad988_level0_row1" class="row_heading level0 row1" >Theobromine</th>
#       <td id="T_ad988_row1_col0" class="data row1 col0" >0.247400</td>
#       <td id="T_ad988_row1_col1" class="data row1 col1" >0.069100</td>
#       <td id="T_ad988_row1_col2" class="data row1 col2" >-0.950200</td>
#       <td id="T_ad988_row1_col3" class="data row1 col3" >-0.121300</td>
#       <td id="T_ad988_row1_col4" class="data row1 col4" >0.097700</td>
#       <td id="T_ad988_row1_col5" class="data row1 col5" >-0.083400</td>
#     </tr>
#     <tr>
#       <th id="T_ad988_level0_row2" class="row_heading level0 row2" >fluctose_arabinise</th>
#       <td id="T_ad988_row2_col0" class="data row2 col0" >0.449200</td>
#       <td id="T_ad988_row2_col1" class="data row2 col1" >0.427500</td>
#       <td id="T_ad988_row2_col2" class="data row2 col2" >0.164600</td>
#       <td id="T_ad988_row2_col3" class="data row2 col3" >0.228800</td>
#       <td id="T_ad988_row2_col4" class="data row2 col4" >-0.163900</td>
#       <td id="T_ad988_row2_col5" class="data row2 col5" >-0.713600</td>
#     </tr>
#     <tr>
#       <th id="T_ad988_level0_row3" class="row_heading level0 row3" >sucrose_maltose</th>
#       <td id="T_ad988_row3_col0" class="data row3 col0" >0.495500</td>
#       <td id="T_ad988_row3_col1" class="data row3 col1" >0.216500</td>
#       <td id="T_ad988_row3_col2" class="data row3 col2" >0.164200</td>
#       <td id="T_ad988_row3_col3" class="data row3 col3" >0.171400</td>
#       <td id="T_ad988_row3_col4" class="data row3 col4" >0.717500</td>
#       <td id="T_ad988_row3_col5" class="data row3 col5" >0.369500</td>
#     </tr>
#     <tr>
#       <th id="T_ad988_level0_row4" class="row_heading level0 row4" >glutamic_acid</th>
#       <td id="T_ad988_row4_col0" class="data row4 col0" >0.373300</td>
#       <td id="T_ad988_row4_col1" class="data row4 col1" >-0.559900</td>
#       <td id="T_ad988_row4_col2" class="data row4 col2" >-0.072300</td>
#       <td id="T_ad988_row4_col3" class="data row4 col3" >0.647700</td>
#       <td id="T_ad988_row4_col4" class="data row4 col4" >-0.310300</td>
#       <td id="T_ad988_row4_col5" class="data row4 col5" >0.161800</td>
#     </tr>
#     <tr>
#       <th id="T_ad988_level0_row5" class="row_heading level0 row5" >Sweetness</th>
#       <td id="T_ad988_row5_col0" class="data row5 col0" >0.336100</td>
#       <td id="T_ad988_row5_col1" class="data row5 col1" >-0.636200</td>
#       <td id="T_ad988_row5_col2" class="data row5 col2" >0.163200</td>
#       <td id="T_ad988_row5_col3" class="data row5 col3" >-0.526700</td>
#       <td id="T_ad988_row5_col4" class="data row5 col4" >0.230500</td>
#       <td id="T_ad988_row5_col5" class="data row5 col5" >-0.353700</td>
#     </tr>
#   </tbody>
# </table>

# %%
import yellowbrick.features as yb
visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
visualizer.fit_transform(X)
visualizer.show()

# %%
pca1 = PCA(n_components= 2)
components = pca1.fit_transform(X_t)
fig = px.scatter(components, x = 0, y = 1, color = Data['Groupping'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6fad77ef-ed7f-470d-8d4d-862494071aac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"s ...

# %%
pca = PCA(n_components=2)

X_pca=pca.fit_transform(X_t)

X_pca
# Out:
# array([[ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 2.71002002,  0.40611207],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [ 0.12322151, -1.68813309],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.4775312 , -0.23400891],
#        [-2.06154758,  0.41492112],
#        [-2.06154758,  0.41492112],
#        [-2.06154758,  0.41492112],
#        [-2.06154758,  0.41492112],
#        [-2.06154758,  0.41492112],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.07693053,  2.14066181],
#        [-1.8739513 ,  0.97233108],
#        [-1.8739513 ,  0.97233108],
#        [-1.8739513 ,  0.97233108],
#        [-1.8739513 ,  0.97233108],
#        [-1.8739513 ,  0.97233108],
#        [-0.6746439 , -0.02322808],
#        [-0.6746439 , -0.02322808],
#        [-0.6746439 , -0.02322808],
#        [-0.6746439 , -0.02322808],
#        [-0.6746439 , -0.02322808],
#        [-0.94771116, -1.05277446],
#        [-0.94771116, -1.05277446],
#        [-0.94771116, -1.05277446],
#        [-0.84988978, -0.98362329],
#        [-0.84988978, -0.98362329],
#        [-0.84988978, -0.98362329]])

# %%
dd=pd.concat([pd.DataFrame(pca.transform(X_t), 
                           columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]), 
              Data[['Groupping']]], axis = 'columns')

dd
# Out:
#          PC1       PC2  Groupping
# 0   2.710020  0.406112          1
# 1   2.710020  0.406112          1
# 2   2.710020  0.406112          1
# 3   2.710020  0.406112          1
# 4   2.710020  0.406112          1
# ..       ...       ...        ...
# 64 -0.947711 -1.052774          6
# 65 -0.947711 -1.052774          6
# 66 -0.849890 -0.983623          6
# 67 -0.849890 -0.983623          6
# 68 -0.849890 -0.983623          6
#
# [69 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
scatter = plt.scatter(dd['PC1'],dd['PC2'],cmap='Set1', c=Data.Groupping.astype('category').cat.codes)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(b=None)
plt.legend(handles=scatter.legend_elements()[0], 
           labels = ['1','2','3','4','5','6'],
           title = "Groupping")
plt.show()
